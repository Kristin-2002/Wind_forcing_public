# %% [markdown]
# # Calulate SEUC transport in INALT20 and observation along 23$^{\circ}$W
#
# For both, model and observations we calculate the central position $ Y_{CM} $ and along-pathway intensity $ INT $ of zonal currents using the algorithm of Hsin (2012).
#
# \begin{equation}
# Y_{CM}(x,t) = \frac{\int_{Z_l}^{Z_u} \int_{Y_{S}}^{Y_{N}} y\ u(x,y,z,t)\ dy\ dz}{\int_{Z_l}^{Z_u} \int_{Y_{S}}^{Y_{N}} u(x,y,z,t)\ dy\ dz}
# \label{equ_Y_CM}
# \end{equation}
#
# \begin{equation}
# INT(x,t) = \int_{Z_l}^{Z_u} \int_{Y_{CM}-W}^{Y_{CM}+W} u(x,y,z,t)\ dy\ dz
# \label{equ_INT}
# \end{equation}
#
#
# where $y$ is latitude, $x$ is longitude, $u$ is zonal velocity, $z$ is depth, $t$ is time, $Z_u$ ($Z_l$) is upper (lower) boundary of the flow, $Y_N$ ($Y_S$) is northern (southern) limit of the flow, and $W$ is the half mean width of the flow.
#
# ![](../figures/INALT20_obs_23w_comparison/1_INALT20_obs_23w_1999_2012.png)
#
# The SEUC total limits are 3$^{\circ}$-7$^{\circ}$S, 30-550m. For transport calculation of the SEUC we use the following boundary conditions:
#
# $Z_u = 25.5\,$kg$\,$m$^{-3}$, $Z_l = 27.0\,$kg$\,$m$^{-3}$, $Y_N = 3^{\circ}$S, $Y_S = 6.5^{\circ}$S
#
# Based on the 23$^{\circ}$W ship section we choose $W = 2^{\circ}$.
#
# The depth of the SEUC core $Z_{CM}$ will be estimated similar to $Y_{CM}$:
#
# \begin{equation}
# Z_{CM}(x,t) = \frac{\int_{Z_l}^{Z_u} \int_{Y_{S}}^{Y_{N}} z\ u(x,y,z,t)\ dy\ dz}{\int_{Z_l}^{Z_u} \int_{Y_{S}}^{Y_{N}} u(x,y,z,t)\ dy\ dz}
# \label{equ_Z_CM}
# \end{equation}
#
# Huettle-Kabus used: 3$^{\circ}$-6$^{\circ}$S,  $\sigma_{\Theta} = 25.5-26.8\,$kg$\,$m$^{-3}$,

# %% [markdown]
# ## Tech preample

# %%
# %matplotlib inline
import os
import dask
import cmocean
import datetime
import nc_time_axis
import cftime
import time
import seawater as sw
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
from pathlib import Path
from scipy.io import loadmat
from datetime import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dask jobqueue and client
# To controle the resources used for parallel computations on computing nodes.

# %%
import dask_jobqueue
cluster = dask_jobqueue.SLURMCluster(
    # Dask worker size
    cores=4, memory='24GB',
    processes=1, # Dask workers per job
    # SLURM job script things
    queue='cluster', walltime='01:30:00',
    # Dask worker network and temporary storage
    interface='ib0', local_directory='$TMPDIR',
    log_directory='./slurm_logs'
)

# %%
from dask.distributed import Client

# %%
client = Client(cluster)
client
# Out:
# <Client: 'tcp://172.18.4.13:37501' processes=0 threads=0, memory=0 B>

# %%
cluster.adapt(
    minimum=1, maximum=20,
)

# %% [markdown]
# ## Output parameters

# %%
script_name = 'INALT20_SEUC_calc_transport'
out_dir_data = Path('../data/'+script_name+'/')
Path(out_dir_data).mkdir(parents=True, exist_ok=True)
out_data_1 = 'INALT20_SEUC_transport'

out_dir_fig = Path('../figures/'+script_name+'/')
Path(out_dir_fig).mkdir(parents=True, exist_ok=True)
out_fig_1 = 'INALT20_'
fig_format = '.png'

savefig = 1; #set one if figures should be saved

# %% [markdown]
# ## Input parameters
# For INALT20

# %%
run_calc_JRA = 1 #set 1 if JRA should be recalculated
run_calc_CORE = 1 #set 1 if CORE should be recalculated
global_data_path = Path("/sfs/fs1/work-geomar1/smomw044/")
JRA_path = "INALT20.L46-KFS10X"
exp_id = "INALT20.L46-KFS10?"

CORE_path = "shared/INALT20.L46-KFS044-S"
CORE_exp_id = "INALT20.L46-KFS044" # INALT COREv2

temp_res = "_5d_" # 5d:5-daily; 1m:monthly; 1y:yearly; 1d:daily(stored currently on TAPE) 
nest_prefix = "1_" # "1_" for high resolution; leave empty for base model

# chunk sizes
chu_x = 100 # None means take the full dataset
chu_y = 100
chu_z = None
chu_t = 1

# variables wanted
vars_want = ['vosaline','votemper','vozocrtx']

# %% [markdown]
# Calculation of EUC - Boundary conditions

# %%
lonlim = [-35, 0]
latlim = [-6,-3.0]
zlim = [0, 550]

## integers
xclim1 = 789 # 30W
xclim2 = 1190 #10W
yclim1 = 1489 # 3S
yclim2 = 1569 # 7S

p_ref = 0 # dbar; reference pressure for potential density calculation
W = 2 #degN, half width of flow
sigma_lim = [24.5,27.0] #kg/m^3, vertical boundaries of flow for INT [Z_u, Z_l]

# %% [markdown]
# Find relevant data files for INALT20

# %% [markdown]
# ## Functions
#
# ### Potential density

# %%
def coords_to_str(latlim,lonlim):
    lats_str=f'{abs(latlim[0])}s' if latlim[0] < 0 else f'{latlim[0]}n'
    latn_str=f'{abs(latlim[1])}s' if latlim[1] < 0 else f'{latlim[1]}n'
    lonw_str=f'{abs(lonlim[0])}w' if lonlim[0] < 0 else f'{lonlim[0]}e'
    lone_str=f'{abs(lonlim[1])}w' if lonlim[1] < 0 else f'{lonlim[1]}e'
    return lats_str,latn_str,lonw_str,lone_str

# %%
def calc_pdens_sw(p_ref,ds):
    
    """ Calculates potential density using the EOS-80 seawater library
    Parameters
    ----------
    pref : int
    reference pressure for potential density calculation
    ds : xr.DataSet containing NEMO3 model output
      ds.deptht  : xr.DataArray (depth in m, positive downwards)
      ds.gphit  : xr.DataArray (latitude grid in degN)
      ds.vosaline  : xr.DataArray (practical salinity(eos 80))
      ds.votemper  : xr.DataArray (potential temp (eos 80))
   
    Returns
    -------
    xr.DataArray
    Data array of potential density calculated using the EOS-80 seawater library [kg/m^3], same dimension as input data arrays
    """
    
    # calculate pressure
    p = xr.apply_ufunc(
    sw.eos80.pres,
    -abs(ds.deptht),ds.gphit,
    dask='parallelized', output_dtypes=[float, ]
    )
    
    # calculate in-situ temperature from potential temperature
    t = xr.apply_ufunc(sw.eos80.temp,
                       ds.vosaline,ds.votemper,p,p_ref,
                       dask = 'parallelized',output_dtypes=[float,])
    
    # compute potential density
    sig = xr.apply_ufunc(sw.eos80.pden,
                         ds.vosaline,t,p,p_ref,
                         dask = 'parallelized',output_dtypes=[float,])
    sig -= 1000
    
    sig['tmask'] = ds.tmask
    sig = sig.where(sig.tmask==1)
    sig.name='sigma_%sm' %p_ref
    sig.attrs['units']='kg/m^3'
    sig.attrs['long_name']='Potential density'
    sig.attrs['reference_pressure']= '%s dbar' %p_ref
    
    return sig

# %% [markdown]
# ### Eastward transport

# %%
def eastw_transport(ucur,dy,dz,z_dim,y_dim):
    ucur = ucur.where(ucur>=0)
    trs_e = (dy*(ucur*dz).sum(dim=z_dim)).sum(dim=y_dim,skipna=True)*1e-6
    
    trs_e.attrs['units']='Sv'
    trs_e.attrs['long_name']='Eastward transport'
    return trs_e

# %% [markdown]
# ### Y$_{CM}$ (central position of a current)

# %%
def YCM(ucur,sigma,lat,dy,dz,sigma_lim,z_dim,y_dim):
    ucur = ucur.where((ucur>=0)&
                      (sigma_lim[0]<=sigma)&
                      (sigma<=sigma_lim[1]))
    y_cm = (dy*(lat*ucur*dz).sum(dim=z_dim)).sum(dim=y_dim,skipna=True)/(
            dy*(ucur*dz).sum(dim=z_dim)).sum(dim=y_dim,skipna=True)
    
    y_cm.attrs['units']='degN'
    y_cm.attrs['name']='Y_CM'
    y_cm.attrs['long_name'] = 'Central latitude'
    return y_cm

# %% [markdown]
# ### Z$_{CM}$ (core depth of a current)

# %%
def ZCM(ucur,sigma,z,dy,dz,sigma_lim,z_dim,y_dim):
    ucur = ucur.where((ucur>=0)&
                      (sigma_lim[0]<=sigma)&
                      (sigma<=sigma_lim[1]))
    z_cm = (dy*(z*ucur*dz).sum(dim=z_dim)).sum(dim=y_dim,skipna=True)/(
            dy*(ucur*dz).sum(dim=z_dim)).sum(dim=y_dim,skipna=True)
    
    z_cm.attrs['units']='m'
    z_cm.attrs['name']='Z_CM'
    z_cm.attrs['long_name'] = 'Central depth'
    return z_cm

# %% [markdown]
# ### INT (eastward transport using cor following algorithm of Hsin 2012)

# %%
def eastw_INT(ucur,sigma,Y_CM,depth,lat,dy,dz,sigma_lim,W,z_dim,y_dim):
    ucur = ucur.where(((ucur>0)&
                      (sigma_lim[0]<=sigma)&
                      (sigma<=sigma_lim[1])&
                      (Y_CM-W < lat)&
                      (Y_CM+W > lat)))
    INT_e = (dy*(ucur*dz).sum(dim=z_dim)).sum(dim=y_dim,skipna=True)*1e-6
    
    INT_e.attrs['units']='Sv'
    INT_e.attrs['name']='INT'
    INT_e.attrs['long_name']='Eastward along-pathway intensity'
    INT_e.attrs['history']='Eastward along-pathway intensity'
    return INT_e

# %%
aux_files = list(sorted(
        (global_data_path/ JRA_path).glob(f"{nest_prefix}[m,n]*.nc")
    ))

aux_files

with dask.config.set(scheduler='synchronous'):
    ds_mesh = xr.open_dataset(
            aux_files[0],
            decode_cf=True,
            chunks={"t":chu_t,"z":chu_z, 
                    "y":chu_y,"x":chu_x})

# %%
# lonlim = [-35, 0]
# latlim = [-6,-4]
# zlim = [30, 550]

# ## integers
# xclim1 = 789
# xclim2 = 1190
# yclim1 = 1489
# yclim2 = 1569
# ds_mesh.gphit.sel(x=600,y=slice(yclim1,yclim2)).squeeze().values
# ds_mesh.glamt.sel(y=1700,x=slice(xclim1,xclim2)).squeeze().values

# %% [markdown]
# ## Run calculations

# %%
def load_INALT20_calc_transp(JRA_files,ds_mesh,model_str,chu_x,chu_y,chu_z,chu_t,
                             xclim1,xclim2,yclim1,yclim2,sigma_lim,p_ref,W_orig,
                            latlim,lonlim):
    with dask.config.set(scheduler='synchronous'):
        ds_JRA_T = xr.open_dataset(
            JRA_files[0],
            chunks={"time_counter":chu_t,
                     "deptht":chu_z, 
                     "y":chu_y, 
                     "x":chu_x},
            decode_cf=True,
            )
    ds_JRA_T = ds_JRA_T.get(['vosaline','votemper'])

    with dask.config.set(scheduler='synchronous'):
        ds_JRA_U = xr.open_dataset(
        JRA_files[1],
        decode_cf=True,
        chunks={"time_counter":chu_t,
                 "depthu":chu_z, 
                 "y":chu_y, 
                 "x":chu_x},)


    ## select region JRA
    ds_JRA_T = ds_JRA_T.assign_coords(gphit=(['y','x'],ds_mesh.gphit.squeeze()))
    ds_JRA_T = ds_JRA_T.assign_coords(glamt=(['y','x'],ds_mesh.glamt.squeeze()))
    ds_JRA_T = ds_JRA_T.drop(['nav_lat','nav_lon'])

    ds_JRA_U = ds_JRA_U.assign_coords(gphiu=(['y','x'],ds_mesh.gphiu.squeeze()))
    ds_JRA_U = ds_JRA_U.assign_coords(glamu=(['y','x'],ds_mesh.glamu.squeeze()))
    ds_JRA_U = ds_JRA_U.drop(['nav_lat','nav_lon'])

    ds_JRA_U['e1u'] = (('y', 'x'), ds_mesh.e1u.squeeze())
    ds_JRA_U['e2u'] = (('y', 'x'), ds_mesh.e2u.squeeze())
    ds_JRA_U['e3u'] = (('depthu','y', 'x'), ds_mesh.e3u_0.squeeze())

    ds_JRA_T.coords['tmask'] = ds_mesh.rename_dims({'z':'deptht'}).tmask.squeeze()
    ds_JRA_U.coords['umask'] = ds_mesh.rename_dims({'z':'depthu'}).umask.squeeze()

    ds_JRA_T = ds_JRA_T.sel(deptht=slice(0,400),
                           x=slice(xclim1,xclim2),
                           y=slice(yclim1,yclim2))

    ds_JRA_U = ds_JRA_U.sel(depthu=slice(0,400),
                           x=slice(xclim1,xclim2),
                           y=slice(yclim1,yclim2))

    # calculate density        
    pdens_JRA = calc_pdens_sw(p_ref,ds_JRA_T)

    ds_JRA_U = ds_JRA_U.isel(x=slice(0,-1)
                    ).swap_dims({'depthu':'depth'}
                    ).rename({'depthu':'depth'})

    with xr.set_options(keep_attrs=True):
        # average on U-Grid
        pdens_JRA =(pdens_JRA.isel(x=slice(None,-1))+pdens_JRA.isel(x=slice(1,None)))/2
        # merge to one dataset
        box_JRA = xr.merge([ds_JRA_U.vozocrtx.where(ds_JRA_U.umask==1),
                    ds_JRA_U.e1u,
                    ds_JRA_U.e2u,
                    ds_JRA_U.e3u,
                    pdens_JRA.swap_dims({'deptht':'depth'}
                    ).rename({'deptht':'depth'})])

    # set coordinates and attributes
    lon = box_JRA.glamu.isel(y=5)
    box_JRA = box_JRA.assign_coords(lon=('x',lon))
    lat = box_JRA.gphit.isel(x=0)
    box_JRA = box_JRA.assign_coords(lat=('y',lat))
    box_JRA = box_JRA.swap_dims({'x':'lon','y':'lat'}
                     ).drop({'gphiu','gphit','glamu','time_centered'})
    box_JRA.lat.attrs['units']='degN'
    box_JRA.lat.attrs['long_name']='Latitude'
    box_JRA.lon.attrs['units']='degE'
    box_JRA.lon.attrs['long_name']='Longitude'
    box_JRA.depth.attrs['units']='m'
    box_JRA.depth.attrs['long_name']='Depth'

    box_JRA.load()
    lat_s,lat_n,lon_w,lon_e=coords_to_str(latlim,lonlim)

    box_JRA.to_netcdf((out_dir_data / f"{JRA_files[1].name[:-9]}lat{lat_s}{lat_n}_lon{lon_w}{lon_e}.nc"),
    engine='netcdf4',
    encoding={'time_counter':{'units':'days since 1900-01-01 00:00:00'}})
    time.sleep(10)

    ## actual calulations
    ds = box_JRA.sel(lat=slice(latlim[0],latlim[1]))
    Y_CM = YCM(ds.vozocrtx,ds.sigma_0m,ds.lat,ds.e2u,ds.e3u,sigma_lim,
               'depth','lat')
    Y_CM.attrs['lat_lim'] = '4degS to 6degS'
    Y_CM.attrs['depth_lim'] = 'Z_u to Z_l (pot dens)'
    Y_CM.attrs['Z_u'] = sigma_lim[0]
    Y_CM.attrs['Z_u_name'] = 'Upper boundary of flow'
    Y_CM.attrs['Z_u_unit'] = 'kg/m^3'
    Y_CM.attrs['Z_l'] = sigma_lim[1]
    Y_CM.attrs['Z_l_name'] = 'Lower boundary of flow'
    Y_CM.attrs['Z_l_unit'] = 'kg/m^3'

    Z_CM = ZCM(ds.vozocrtx,ds.sigma_0m,ds.depth,ds.e2u,ds.e3u,sigma_lim,
               'depth','lat')
    Z_CM.attrs['lat_lim'] = '4degS to 6degS'
    Z_CM.attrs['depth_lim'] = 'Z_u to Z_l (pot dens)'
    Z_CM.attrs['Z_u'] = sigma_lim[0]
    Z_CM.attrs['Z_u_name'] = 'Upper boundary of flow'
    Z_CM.attrs['Z_u_unit'] = 'kg/m^3'
    Z_CM.attrs['Z_l'] = sigma_lim[1]
    Z_CM.attrs['Z_l_name'] = 'Lower boundary of flow'
    Z_CM.attrs['Z_l_unit'] = 'kg/m^3'

    INT = eastw_INT(box_JRA.vozocrtx,box_JRA.sigma_0m,Y_CM,ds.depth,box_JRA.lat,
              box_JRA.e2u,box_JRA.e3u,sigma_lim,W,'depth','lat')
    INT.attrs['lat_lim'] = 'Y_CM-W (min 7degS) to Y_CM+W (max 3degS)'
    INT.attrs['W_name'] = 'Half mean width of flow'
    INT.attrs['W_unit'] = 'degN'
    INT.attrs['W'] = W_orig
    INT.attrs['depth_lim'] = 'Z_u to Z_l (pot dens)'
    INT.attrs['Z_u'] = sigma_lim[0]
    INT.attrs['Z_u_name'] = 'Upper boundary of flow'
    INT.attrs['Z_u_unit'] = 'kg/m^3'
    INT.attrs['Z_l'] = sigma_lim[1]
    INT.attrs['Z_l_name'] = 'Lower boundary of flow'
    INT.attrs['Z_l_unit'] = 'kg/m^3'


    with xr.set_options(keep_attrs=True):
        SEUC_JRA = xr.merge([
            Y_CM.rename('Y_CM'),Z_CM.rename('Z_CM'),
            INT.rename('INT')
        ])


    SEUC_JRA.attrs['title'] = f'SEUC transports in INALT20 {model_str}'
    SEUC_JRA.attrs['timeStamp'] = '%s' % datetime.now()
    SEUC_JRA.attrs['history'] = 'Original model output modified using INALT20_SEUC_calc_transport.ipynb'

    SEUC_JRA.to_netcdf((out_dir_data / f"{JRA_files[1].name[:-9]}{out_data_1}{'.nc'}"),
    engine='netcdf4',
    encoding={'time_counter':{'units':'days since 1900-01-01 00:00:00'}})
    return SEUC_JRA,box_JRA

# %%
# %%time
for restr_years in range(2018,2019):
    print (restr_years)
    # JRA
    JRA_files = list(sorted(
        (global_data_path / JRA_path ).glob(
            f"{nest_prefix}{exp_id}{temp_res}{restr_years}????_{restr_years}????_grid_[T,U].nc")
    ))

    SEUC_JRA,box_JRA = load_INALT20_calc_transp(JRA_files,ds_mesh,'JRA',chu_x,chu_y,chu_z,chu_t,
                        xclim1,xclim2,yclim1,yclim2,sigma_lim,p_ref,W,
                        latlim,lonlim)
    time.sleep(10) 

    # CORE
    if restr_years<2010:
        CORE_files = list(sorted(
            (global_data_path / CORE_path ).glob(
                f"{nest_prefix}{CORE_exp_id}{temp_res}{restr_years}????_{restr_years}????_grid_[T,U].nc"
            )))
        SEUC_CORE,box_CORE = load_INALT20_calc_transp(CORE_files,ds_mesh,'CORE',chu_x,chu_y,chu_z,chu_t,
                            xclim1,xclim2,yclim1,yclim2,sigma_lim,p_ref,W,
                            latlim,lonlim)
        time.sleep(10)

cluster.close()
# Out:
# 2018
# distributed.scheduler - ERROR - Couldn't gather keys {"('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 13)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 17, 10)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 1, 17)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 25)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 14, 4)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 18)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 26)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 12, 6)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 16)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 6, 0)": ['tcp://172.18.4.126:41065'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 12, 8)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 20)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 15, 0)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 18, 0)": ['tcp://172.18.5.91:40039'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 11)": ['tcp://172.18.4.126:41065'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 10)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 2, 19)": ['tcp://172.18.5.91:40039'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 15)": ['tcp://172.18.4.126:41065'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 17, 21)": ['tcp://172.18.5.91:40039'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 2)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 13)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 27)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 24)": ['tcp://172.18.4.126:41065'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 5)": ['tcp://172.18.4.126:41065'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 25)": ['tcp://172.18.5.91:40039'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 1)": ['tcp://172.18.5.91:40039'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 18, 4)": ['tcp://172.18.5.91:40039'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 15, 18)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 15)": ['tcp://172.18.5.91:40039'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 11)": ['tcp://172.18.4.126:41065'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 1, 20)": ['tcp://172.18.5.91:40039'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 17)": ['tcp://172.18.5.91:40039'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 14, 1)": ['tcp://172.18.4.126:41065'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 15)": ['tcp://172.18.4.126:45183'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 2, 23)": ['tcp://172.18.5.91:40039'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 19)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 14)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 10)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 0)": ['tcp://172.18.4.126:41065'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 2)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 17)": ['tcp://172.18.4.126:41065'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 21)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 8, 13)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 18)": ['tcp://172.18.4.126:46029'], "('getitem-8dfb4752d109356284d9737e2e275885', 0, 1, 23)": ['tcp://172.18.4.1 ...
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 13)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 17, 10)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 1, 17)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 25)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 14, 4)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 18)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 26)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 12, 6)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 16)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 6, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 12, 8)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 20)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 15, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 18, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 11)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 10)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 2, 19)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 15)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 17, 21)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 2)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 13)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 27)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 24)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 5)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 25)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 1)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 18, 4)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 15, 18)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 15)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 11)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 1, 20)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 17)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 14, 1)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 15)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 2, 23)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 19)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 14)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 10)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 2)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 17)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 21)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 8, 13)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 18)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 1, 23)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 18)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 15)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 10)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 23)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 25)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 18, 13)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 14, 25)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 11)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 7)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 5)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 14)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 25)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 12, 12)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 6, 20)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 11)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 11)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 2)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 17)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 26)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 7)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 13)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 15, 17)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 1, 3)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 12)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 17, 19)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 2, 14)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 10, 12)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 14, 14)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 2, 17)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 6, 6)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 4)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 6, 21)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 17, 20)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 10)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 9)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 14)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 19)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 6)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 7)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 17, 17)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 12, 10)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 4)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 23)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 8)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 20)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 6, 23)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 22)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 1, 11)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 14)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 14)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 24)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 16)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 18, 15)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 6, 14)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 8, 16)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 26)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 21)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 23)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 5)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 21)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 14, 6)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 18)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 17)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 1, 15)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 21)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 15, 20)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 23)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 2, 1)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 5)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 14, 11)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 15)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 4)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 27)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 17, 25)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 3)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 1)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 15, 7)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 12, 24)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 14, 5)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 5)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 20)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 9)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 21)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 3)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 22)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 12, 27)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 6, 10)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 11)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 2, 10)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 15, 3)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 24)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 18, 10)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 9)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 4, 20)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 8)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 5, 16)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 14)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 1)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 15, 19)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 12)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 17, 1)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 2)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 7, 24)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 17, 12)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 17)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 2, 18)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 6)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 14, 17)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 10)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 12, 9)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.5.91:40039'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 18, 26)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 0, 13)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 15, 6)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 27)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 9, 21)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 12, 13)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:46029'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 11, 4)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 6, 22)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 27)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 16, 21)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:45183'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 13, 7)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.18.4.126:41065'], ('getitem-8dfb4752d109356284d9737e2e275885', 0, 3, 15)
# NoneType: None
# CPU times: user 27.8 s, sys: 18.8 s, total: 46.6 s
# Wall time: 2min 20s
# distributed.client - ERROR - Failed to reconnect to scheduler after 10.00 seconds, closing client
# _GatheringFuture exception was never retrieved
# future: <_GatheringFuture finished exception=CancelledError()>
# asyncio.exceptions.CancelledError
# distributed.deploy.adaptive_core - ERROR - Adaptive stopping due to error Timed out trying to connect to tcp://172.18.4.13:37501 after 10 s
